# %%
# %pylab
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy.signal import argrelextrema

# %%
import glob
from matplotlib import cm

# %%
matplotlib.rcParams['figure.figsize'] = [10.5,7]
matplotlib.rcParams.update({'font.size': 20})

# %%
# Constantes de la physique
# ABSOLUMENT RECHARGER APRÈS AVOIR EXECUTÉ LES CASES D'IMPORT AU DESSUS

C_e = 1.602e-19        # Coulomb
kb = 1.38064852*1e-23  # Boltzman
m_Ca = 40.078*1.66054e-27 # masse Ca 40.078
m_GM = 1e6*1.66054e-27 # la masse de la GMol
eps0 = 8.854187*1e-12  # permittivité électrique du vide


r0 = 2.5e-3 # 2.5e-3   # rayon piège Ca+
d0 = (4e-3)/2            # longueur piège Ca+
Omega = 2.045e6*2*pi # 2.047e6
bk = 4 # nombre de barreaux par groupe (2 -> 4-pole , 4 -> 8-pole ...)

mkappa = 0.23          # écrantage piège réel GiantMol
wzLC = (2*pi*90806.9982303)**2
kappa_simion = m_Ca*d0**2*wzLC/(2*C_e)
print('%s = %f' % ('$\kappa_{simion}$',kappa_simion) )

zeta = kappa_simion*r0**2/d0**2
# Out:
# $\kappa_{simion}$ = 0.270471

# %%
Udc = 1
Urf = 42.43
omega_z_2 = 2*C_e*mkappa*Udc/m_Ca/d0**2
omega_z_2_simion = 2*C_e*kappa_simion*Udc/m_Ca/d0**2
omega_x_2 = 2*(C_e*Urf/m_Ca/Omega/r0**2)**2
omega_r_2 = omega_x_2 - 0.5*omega_z_2

qx = 4*C_e*Urf/(m_Ca*r0**2*Omega**2)
ax = 8*C_e*0/(m_Ca*r0**2*Omega**2)
az = 2*omega_z_2/Omega**2

print('alpha =',omega_z_2/omega_x_2)
print('qx =',qx)
print('ax =',ax)
print('az =',az)
print('f_z =',sqrt(omega_z_2)/2/pi)
print('f_x =',sqrt(omega_x_2)/2/pi)
print('f_r =',sqrt(omega_r_2)/2/pi)
# Out:
# alpha = 0.08556990464270328
# qx = 0.39592577324621586
# ax = 0.0
# az = 0.0033534250473806
# f_z = 83738.00625693168
# f_x = 286260.93958887755
# f_r = 280070.1674373121

# %% [markdown]
# # Extraction de données

# %%
filename=[]

# %%
# sélection des fichiers (Python 3)
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()

file_path = filedialog.askopenfilename(initialdir = '/home/adrian/Documents/Mesures',multiple=True)
print(file_path)
# Out:
# ('/home/adrian/Documents/Mesures/GiantMol_Ions/20180511/balayage_2/tickle_170vpp_2500mv_0_0_300k_100k_000.dat', '/home/adrian/Documents/Mesures/GiantMol_Ions/20180511/balayage_2/tickle_170vpp_2500mv_0_0_400k_200k_000.dat', '/home/adrian/Documents/Mesures/GiantMol_Ions/20180511/balayage_2/tickle_170vpp_2500mv_0_0_500k_300k_000.dat')

# %%
file_path = file_path[::-1]
file_path
# Out:
# ('/home/adrian/Documents/Mesures/GiantMol_Ions/20180511/balayage_2/tickle_170vpp_2500mv_0_0_500k_300k_000.dat',
#  '/home/adrian/Documents/Mesures/GiantMol_Ions/20180511/balayage_2/tickle_170vpp_2500mv_0_0_400k_200k_000.dat',
#  '/home/adrian/Documents/Mesures/GiantMol_Ions/20180511/balayage_2/tickle_170vpp_2500mv_0_0_300k_100k_000.dat')

# %%
# # sélection des fichiers (Python 2)
# from Tkinter import Tk
# from tkFileDialog import askopenfilename

# Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
# filename = askopenfilename(multiple=True) # show an "Open" dialog box and return the path to the selected file
# print(filename)

# %%
filename=file_path
m=len(filename)
n=len(loadtxt('%s' %filename[1],usecols=(0),unpack=True))
shape=(m,n)
# Temps, PM, Tension Pzt bleu
TP = zeros(shape)
PM = zeros(shape)
VB = zeros(shape)
for k in range(0,len(filename),1):
    TP[:][k],PM[:][k],VB[:][k] = loadtxt('%s' %filename[k],usecols=(0,1,3),unpack=True)

# %%
# plot tickle

figure('Plot tickle').clf()
for k in range(3):
    freq=linspace(100*k,200+100*k,1999)
    plot(freq,PM[k])
# plot(freq[1000-2:-1],PM[1],'r')
xlabel('Tickle frequency [kHz]')
ylabel('Fluorescence [cnt/250ms]')
grid()
plt.tight_layout()

# %%
PM_all = [list(PM[0][:1+len(PM[k])//2])]
for k in range(3):
    PM_all.append(PM[k][len(PM[k])//2:])
# PM_all = [list(PM[0][:1+len(PM[k])//2]),PM_all]
PM_all = [item for sublist in PM_all for item in sublist]
# PM_all = [list(PM[0][:len(PM[k])//2]),PM_all]

print(len(PM[k]))
print(len(PM_all))
print(PM_all)
# Out:
# 1999
# 4000
# [109280.0, 109835.0, 110457.0, 110543.0, 108742.0, 108535.0, 110084.0, 110437.0, 109579.0, 108597.0, 108702.0, 107513.0, 108708.0, 109039.0, 109215.0, 107161.0, 107935.0, 106807.0, 108934.0, 109902.0, 108554.0, 108829.0, 107746.0, 106099.0, 107611.0, 105845.0, 106102.0, 107059.0, 107744.0, 108282.0, 107753.0, 108702.0, 107435.0, 105910.0, 105537.0, 106050.0, 108087.0, 107481.0, 105730.0, 107858.0, 108616.0, 108798.0, 109084.0, 109709.0, 108576.0, 106330.0, 108120.0, 107553.0, 106624.0, 106577.0, 107867.0, 109558.0, 109413.0, 111382.0, 109793.0, 106809.0, 105682.0, 105435.0, 106488.0, 107736.0, 108386.0, 110726.0, 111190.0, 110795.0, 110862.0, 111186.0, 111936.0, 110913.0, 111730.0, 109965.0, 110134.0, 110711.0, 111183.0, 112140.0, 112717.0, 113456.0, 112543.0, 110192.0, 108860.0, 110404.0, 107289.0, 107638.0, 107882.0, 107695.0, 109069.0, 108698.0, 109157.0, 107910.0, 107660.0, 108976.0, 107489.0, 109462.0, 108294.0, 108802.0, 107145.0, 106961.0, 107859.0, 108244.0, 107856.0, 110220.0, 107834.0, 108175.0, 106988.0, 106692.0, 107024.0, 105903.0, 105803.0, 106442.0, 105601.0, 106651.0, 106525.0, 106417.0, 108277.0, 107037.0, 106881.0, 107709.0, 108238.0, 107863.0, 107435.0, 108799.0, 108387.0, 109320.0, 109581.0, 107846.0, 109275.0, 107862.0, 108741.0, 110339.0, 109646.0, 107032.0, 108651.0, 106063.0, 105583.0, 105574.0, 106727.0, 108146.0, 108145.0, 107791.0, 107118.0, 106683.0, 107593.0, 106972.0, 107708.0, 107609.0, 106421.0, 107516.0, 107999.0, 108529.0, 107490.0, 107
]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-18d559cae36d> in <module>()
# ----> 1 print(testm_min[0])
#       2 int(PM_all[testm_min[0]])
#
# NameError: name 'testm_min' is not defined

# %%
testm_min = argrelextrema(array(PM_all),less,order=150)
testm_min = delete(testm_min,(0,1,2,3,7,8))

my_udc = 2.5
f_r = sqrt(omega_r_2)/2/pi
f_z = sqrt(omega_z_2_simion*my_udc)/2/pi

fig=figure('Total_plot',clear='True')
fig.set_size_inches(12, 7)
ax = fig.add_subplot(1, 1, 1)

# for k in range(3):
#     freq=linspace(500-100*k,300-100*k,1999)
#     plot(freq,PM[k],ls='--',alpha = 0.5)

freq=linspace(500,100,4000)

plt.plot(freq,PM_all,color='xkcd:azul',linewidth=1.5,alpha=1,ls='-')
plt.vlines(x=freq[testm_min],ymin=0,ymax=80000,linestyle='--')
plt.vlines(x=f_r/1000,ymin=0,ymax=120000,linestyle=':')
plt.vlines(x=f_z/1000,ymin=0,ymax=120000,linestyle=':')
# plt.vlines(x=130.5*2,ymin=0,ymax=80000,linestyle=':',color='red')

# ylim(-1500,100000)
# title('Tickle {}'.format(file_path[0][31:39]))
ax.set_xlabel('Frequency (kHz)')
ax.set_ylabel('Fluorescence (counts)')
ax.set_xlim(98,502)
# ax.set_ylim(0,120000)
# legend([file_path[0][40:60]])

# toto = ['$f_z$','$2f_z$','$f_x$','$f_y$']
toto = ['?','$f_y$','$f_x$','$2f_z$','$f_z$']

font = {'family': 'sans-serif',
        'color':  'xkcd:vermillion',
        'weight': 'normal',
        'size': 20,
        }
props = dict(facecolor='white', alpha=1)
ypos=[65000, 60000, 35500, 62000]
for k in range(len(testm_min)):
    plt.text(freq[testm_min[k]]+3.5,int(PM_all[testm_min[k]])-6000,'{} = {:.1f}'.format(toto[k],freq[testm_min[k]]),
             fontdict=font,rotation='90',bbox=props)

plt.text(f_r/1000+4,117000,r'$f_r^{{{}}}$={:.1f}'.format('sim',f_r/1000),
             fontdict=font,rotation='0',bbox=props)
plt.text(f_z/1000+4,117000,f'$f_z^{{sim}}$={f_z/1000:.1f}',
             fontdict=font,rotation='0',bbox=props)

ax.xaxis.set_major_locator(matplotlib.ticker.MultipleLocator(base=50))
ax.legend(['$U_{RF}=42.43$ V \n $V_{END}=2.5$ V \n $T_{int}=250$ ms \n $\delta f = 0.1$ kHz'],
          loc = 'lower right')
ax.grid()
plt.tight_layout()
savefig('tickle_demo.png')

# %%
'$x_{ert}$'
# Out:
# '$x_{ert}$'

# %%
sqrt(omega_z_2_simion*2.5)/2/pi/1000,sqrt(omega_z_2*2.5)/2/pi/1000
# Out:
# (143.5784709453136, 132.4014132466675)

# %%
print('{}{}'.format('Minimums trouvés : ', argrelextrema(PM[0],less,order=200)))
print('{}{:.1f}{}'.format('Minimums vrais 0: ', freq[testm_min[0]],' kHz'))
# Out:
# Minimums trouvés : (array([  31,  424,  998, 1309, 1743]),)
# Minimums vrais 0: 208.0 kHz

# %%
Uend=np.array([2.5,3.5,4.5,5.5,6.5]) # ne pas /2 SÛR

# mesures
w1=np.array([263.5,257,249,241,233.5])*2*pi*1e3 # plus petit des deux wr
w2=np.array([280,274,267,260,252.5])*2*pi*1e3 # plus grand des deux wr
wz=np.array([258/2,298/2,178,197.5,215])*2*pi*1e3
